# %% [markdown]
# # Time complexity

# %% [markdown]
# ref : https://www.youtube.com/watch?v=D6xkbGLQesk&list=WL&index=70

# %%
import time
import numpy as np
import pandas as pd

# %% [markdown]
# ## time complexity: linear time

# %%
results = []
for run in range(np.random.randint(0,1000)): # multiple run
    
    start = time.time() # start time 
    array = [np.random.randint(0,10) for x in range(np.random.randint(1,100))] # generate an array
    
    # add item from the arrays 
    total = 0
    for j in array:
        total += i
    results.append([time.time()-start,len(array)]) # end time + length of the array

# %%
# Plot mean time per array lenght
pd.DataFrame(results).groupby(1)[[0]].mean().plot(title='Mean runtime per array length');

# %% [markdown]
# as the size of the inputs increase, the time increases linearity

# %% [markdown]
# Time complexity:
#
# - linear time **Big O of n = O(n)**
# - constant time **Big O of 1 = O(1)**
# - quadratic time **O(n^2)**
